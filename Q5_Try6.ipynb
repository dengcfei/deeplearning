# %%
import os
from keras import layers
from keras import models
from keras import optimizers


# fill this part
from keras.preprocessing.image import ImageDataGenerator



base_dir = 'cat_dog_car_bike' # very important: do not change this!
train_dir= os.path.join(base_dir, 'train') # very important: do not change this!
validation_dir= os.path.join(base_dir, 'val') # very important: do not change this!


train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=90,
      width_shift_range=0.4,
      height_shift_range=0.4,
      shear_range=0.9,
      zoom_range=0.8,
      horizontal_flip=True,
      vertical_flip=True,
      fill_mode='reflect'
)
test_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical')
validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')
# Out:
# Using TensorFlow backend.
# Found 1675 images belonging to 4 classes.
# Found 835 images belonging to 4 classes.

# %%
from matplotlib import pyplot
# prepare iterator
# generate samples and plot
images, labels = train_generator.next()
print(images.shape[0])

for i in range(images.shape[0]):
    print(i)
    # define subplot
    pyplot.subplot(330 + 1 + i)
    # convert to unsigned integers for viewing
    image = images[i].astype('uint8')
    # plot raw pixel data
    pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
conv_base.summary()
for i, layer in enumerate(conv_base.layers):
    print(i, layer.name, layer.trainable)

# %%
from keras.applications import VGG16
conv_base = VGG16(weights='imagenet',
                  include_top=False, 
                  input_shape=(150, 150, 3))

# %%
for i, layer in enumerate(conv_base.layers):
    print(i, layer.name, layer.trainable)

# %%
from keras.applications import VGG16
from keras import regularizers
conv_base = VGG16(weights='imagenet',
                  include_top=False, 
                  input_shape=(150, 150, 3))

model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

for layer in conv_base.layers[:15]:
    layer.trainable = False
#for i, layer in enumerate(conv_base.layers):
#    print(i, layer.name, layer.trainable)
#model.summary()
model.compile(loss='categorical_crossentropy',
              #optimizer=optimizers.RMSprop(lr=0.001),
              optimizer=optimizers.adam(lr=0.0001),
              metrics=['acc'])

history = model.fit_generator(
      train_generator,
      #steps_per_epoch=60,
      epochs=100,
      validation_data=validation_generator,
      #validation_steps=4
)
# Out:
# Epoch 1/100
# 53/53 [==============================] - 19s 352ms/step - loss: 1.0408 - acc: 0.5373 - val_loss: 0.0580 - val_acc: 0.7641
# Epoch 2/100
# 53/53 [==============================] - 16s 301ms/step - loss: 0.7173 - acc: 0.6878 - val_loss: 0.2301 - val_acc: 0.7868
# Epoch 3/100
# 53/53 [==============================] - 16s 300ms/step - loss: 0.6130 - acc: 0.7361 - val_loss: 0.0134 - val_acc: 0.8659
# Epoch 4/100
# 53/53 [==============================] - 16s 298ms/step - loss: 0.5958 - acc: 0.7439 - val_loss: 0.2008 - val_acc: 0.8539
# Epoch 5/100
# 53/53 [==============================] - 16s 293ms/step - loss: 0.5599 - acc: 0.7761 - val_loss: 0.0098 - val_acc: 0.8874
# Epoch 6/100
# 53/53 [==============================] - 16s 301ms/step - loss: 0.5515 - acc: 0.7833 - val_loss: 0.0096 - val_acc: 0.9281
# Epoch 7/100
# 53/53 [==============================] - 16s 304ms/step - loss: 0.5462 - acc: 0.7654 - val_loss: 0.0093 - val_acc: 0.9341
# Epoch 8/100
# 53/53 [==============================] - 16s 307ms/step - loss: 0.5351 - acc: 0.7815 - val_loss: 0.0095 - val_acc: 0.9234
# Epoch 9/100
# 53/53 [==============================] - 16s 307ms/step - loss: 0.4893 - acc: 0.7904 - val_loss: 0.0092 - val_acc: 0.9281
# Epoch 10/100
# 53/53 [==============================] - 16s 304ms/step - loss: 0.4793 - acc: 0.8036 - val_loss: 0.0092 - val_acc: 0.9293
# Epoch 11/100
# 53/53 [==============================] - 17s 319ms/step - loss: 0.4725 - acc: 0.7982 - val_loss: 0.0110 - val_acc: 0.9329
# Epoch 12/100
# 53/53 [==============================] - 16s 305ms/step - loss: 0.4482 - acc: 0.8221 - val_loss: 0.0091 - val_acc: 0.9377
# Epoch 13/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.4420 - acc: 0.8179 - val_loss: 0.0092 - val_acc: 0.9377
# Epoch 14/100
# 53/53 [==============================] - 16s 297ms/step - loss: 0.4394 - acc: 0.8245 - val_loss: 0.0223 - val_acc: 0.9234
# Epoch 15/100
# 53/53 [==============================] - 17s 326ms/step - loss: 0.4077 - acc: 0.8412 - val_loss: 0.0092 - val_acc: 0.9269
# Epoch 16/100
# 53/53 [==============================] - 17s 320ms/step - loss: 0.4167 - acc: 0.8382 - val_loss: 0.0093 - val_acc: 0.9401
# Epoch 17/100
# 53/53 [==============================] - 16s 310ms/step - loss: 0.3778 - acc: 0.8543 - val_loss: 0.0089 - val_acc: 0.9545
# Epoch 18/100
# 53/53 [==============================] - 16s 295ms/step - loss: 0.4253 - acc: 0.8263 - val_loss: 0.0089 - val_acc: 0.9461
# Epoch 19/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.3426 - acc: 0.8639 - val_loss: 0.0088 - val_acc: 0.9509
# Epoch 20/100
# 53/53 [==============================] - 17s 314ms/step - loss: 0.3864 - acc: 0.8454 - val_loss: 0.0088 - val_acc: 0.9605
# Epoch 21/100
# 53/53 [==============================] - 16s 309ms/step - loss: 0.3624 - acc: 0.8537 - val_loss: 0.0088 - val_acc: 0.9353
# Epoch 22/100
# 53/53 [==============================] - 16s 300ms/step - loss: 0.4128 - acc: 0.8388 - val_loss: 0.0087 - val_acc: 0.9629
# Epoch 23/100
# 53/53 [==============================] - 16s 308ms/step - loss: 0.3459 - acc: 0.8687 - val_loss: 0.0087 - val_acc: 0.9629
# Epoch 24/100
# 53/53 [==============================] - 16s 301ms/step - loss: 0.3731 - acc: 0.8412 - val_loss: 0.0087 - val_acc: 0.9617
# Epoch 25/100
# 53/53 [==============================] - 16s 301ms/step - loss: 0.3470 - acc: 0.8597 - val_loss: 0.0131 - val_acc: 0.8934
# Epoch 26/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.3377 - acc: 0.8770 - val_loss: 0.0087 - val_acc: 0.9341
# Epoch 27/100
# 53/53 [==============================] - 16s 299ms/step - loss: 0.3534 - acc: 0.8615 - val_loss: 0.0086 - val_acc: 0.9581
# Epoch 28/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.3207 - acc: 0.8633 - val_loss: 0.0086 - val_acc: 0.9557
# Epoch 29/100
# 53/53 [==============================] - 16s 310ms/step - loss: 0.3519 - acc: 0.8669 - val_loss: 0.0085 - val_acc: 0.9617
# Epoch 30/100
# 53/53 [==============================] - 16s 299ms/step - loss: 0.3305 - acc: 0.8752 - val_loss: 0.0085 - val_acc: 0.9593
# Epoch 31/100
# 53/53 [==============================] - 16s 299ms/step - loss: 0.3382 - acc: 0.8752 - val_loss: 0.0085 - val_acc: 0.9365
# Epoch 32/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.3404 - acc: 0.8627 - val_loss: 0.0098 - val_acc: 0.9401
# Epoch 33/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.3298 - acc: 0.8651 - val_loss: 0.0084 - val_acc: 0.9533
# Epoch 34/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.3310 - acc: 0.8704 - val_loss: 0.0084 - val_acc: 0.9629
# Epoch 35/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.3119 - acc: 0.8794 - val_loss: 0.0084 - val_acc: 0.9473
# Epoch 36/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.3474 - acc: 0.8597 - val_loss: 0.0083 - val_acc: 0.9593
# Epoch 37/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.2877 - acc: 0.8955 - val_loss: 0.0083 - val_acc: 0.9689
# Epoch 38/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.3110 - acc: 0.8788 - val_loss: 0.0083 - val_acc: 0.9677
# Epoch 39/100
# 53/53 [==============================] - 16s 307ms/step - loss: 0.3249 - acc: 0.8776 - val_loss: 0.0082 - val_acc: 0.9485
# Epoch 40/100
# 53/53 [==============================] - 16s 300ms/step - loss: 0.3404 - acc: 0.8591 - val_loss: 0.0082 - val_acc: 0.9605
# Epoch 41/100
# 53/53 [==============================] - 16s 299ms/step - loss: 0.3229 - acc: 0.8675 - val_loss: 0.0082 - val_acc: 0.9713
# Epoch 42/100
# 53/53 [==============================] - 16s 301ms/step - loss: 0.2831 - acc: 0.8806 - val_loss: 0.0082 - val_acc: 0.9593
# Epoch 43/100
# 53/53 [==============================] - 16s 309ms/step - loss: 0.3047 - acc: 0.8890 - val_loss: 0.0082 - val_acc: 0.9701
# Epoch 44/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.3106 - acc: 0.8830 - val_loss: 0.0081 - val_acc: 0.9593
# Epoch 45/100
# 53/53 [==============================] - 16s 297ms/step - loss: 0.2991 - acc: 0.8794 - val_loss: 0.0081 - val_acc: 0.9581
# Epoch 46/100
# 53/53 [==============================] - 16s 298ms/step - loss: 0.3193 - acc: 0.8794 - val_loss: 0.0081 - val_acc: 0.9641
# Epoch 47/100
# 53/53 [==============================] - 16s 304ms/step - loss: 0.3074 - acc: 0.8937 - val_loss: 0.0081 - val_acc: 0.9665
# Epoch 48/100
# 53/53 [==============================] - 16s 307ms/step - loss: 0.2776 - acc: 0.8997 - val_loss: 0.0080 - val_acc: 0.9449
# Epoch 49/100
# 53/53 [==============================] - 16s 304ms/step - loss: 0.2948 - acc: 0.8800 - val_loss: 0.0080 - val_acc: 0.9593
# Epoch 50/100
# 53/53 [==============================] - 15s 289ms/step - loss: 0.2987 - acc: 0.8907 - val_loss: 0.0080 - val_acc: 0.9449
# Epoch 51/100
# 53/53 [==============================] - 16s 305ms/step - loss: 0.3005 - acc: 0.8764 - val_loss: 0.0080 - val_acc: 0.9605
# Epoch 52/100
# 53/53 [==============================] - 16s 307ms/step - loss: 0.2567 - acc: 0.9027 - val_loss: 0.0079 - val_acc: 0.9593
# Epoch 53/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.2928 - acc: 0.8878 - val_loss: 0.0079 - val_acc: 0.9665
# Epoch 54/100
# 53/53 [==============================] - 16s 311ms/step - loss: 0.2550 - acc: 0.9063 - val_loss: 0.0079 - val_acc: 0.9641
# Epoch 55/100
# 53/53 [==============================] - 16s 305ms/step - loss: 0.2932 - acc: 0.8884 - val_loss: 0.0079 - val_acc: 0.9629
# Epoch 56/100
# 53/53 [==============================] - 17s 317ms/step - loss: 0.2798 - acc: 0.8866 - val_loss: 0.0078 - val_acc: 0.9605
# Epoch 57/100
# 53/53 [==============================] - 16s 305ms/step - loss: 0.2787 - acc: 0.8913 - val_loss: 0.0078 - val_acc: 0.9629
# Epoch 58/100
# 53/53 [==============================] - 16s 311ms/step - loss: 0.2689 - acc: 0.9045 - val_loss: 0.0078 - val_acc: 0.9437
# Epoch 59/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.2994 - acc: 0.8872 - val_loss: 0.0169 - val_acc: 0.9497
# Epoch 60/100
# 53/53 [==============================] - 17s 313ms/step - loss: 0.2707 - acc: 0.8919 - val_loss: 0.0077 - val_acc: 0.9617
# Epoch 61/100
# 53/53 [==============================] - 16s 305ms/step - loss: 0.2775 - acc: 0.8985 - val_loss: 0.0077 - val_acc: 0.9629
# Epoch 62/100
# 53/53 [==============================] - 22s 408ms/step - loss: 0.2725 - acc: 0.8919 - val_loss: 0.0077 - val_acc: 0.9629
# Epoch 63/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.2742 - acc: 0.8949 - val_loss: 0.0077 - val_acc: 0.9641
# Epoch 64/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.2731 - acc: 0.8907 - val_loss: 0.0076 - val_acc: 0.9617
# Epoch 65/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.2593 - acc: 0.8955 - val_loss: 0.0076 - val_acc: 0.9545
# Epoch 66/100
# 53/53 [==============================] - 17s 326ms/step - loss: 0.3002 - acc: 0.8890 - val_loss: 0.0076 - val_acc: 0.9617
# Epoch 67/100
# 53/53 [==============================] - 16s 298ms/step - loss: 0.2966 - acc: 0.8907 - val_loss: 0.0076 - val_acc: 0.9593
# Epoch 68/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.2563 - acc: 0.9045 - val_loss: 0.0076 - val_acc: 0.9701
# Epoch 69/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.2869 - acc: 0.8884 - val_loss: 0.0075 - val_acc: 0.9473
# Epoch 70/100
# 53/53 [==============================] - 16s 299ms/step - loss: 0.2827 - acc: 0.8931 - val_loss: 0.0075 - val_acc: 0.9677
# Epoch 71/100
# 53/53 [==============================] - 16s 297ms/step - loss: 0.2597 - acc: 0.9009 - val_loss: 0.0075 - val_acc: 0.9677
# Epoch 72/100
# 53/53 [==============================] - 16s 310ms/step - loss: 0.2687 - acc: 0.9027 - val_loss: 0.0075 - val_acc: 0.9701
# Epoch 73/100
# 53/53 [==============================] - 16s 298ms/step - loss: 0.2480 - acc: 0.9093 - val_loss: 0.0075 - val_acc: 0.9593
# Epoch 74/100
# 53/53 [==============================] - 16s 297ms/step - loss: 0.2768 - acc: 0.8949 - val_loss: 0.0075 - val_acc: 0.9605
# Epoch 75/100
# 53/53 [==============================] - 16s 300ms/step - loss: 0.2599 - acc: 0.9027 - val_loss: 0.0076 - val_acc: 0.9653
# Epoch 76/100
# 53/53 [==============================] - 17s 313ms/step - loss: 0.2744 - acc: 0.8961 - val_loss: 0.0074 - val_acc: 0.9629
# Epoch 77/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.2741 - acc: 0.9003 - val_loss: 0.0074 - val_acc: 0.9641
# Epoch 78/100
# 53/53 [==============================] - 16s 295ms/step - loss: 0.2779 - acc: 0.8872 - val_loss: 0.0074 - val_acc: 0.9545
# Epoch 79/100
# 53/53 [==============================] - 16s 300ms/step - loss: 0.2511 - acc: 0.9021 - val_loss: 0.0074 - val_acc: 0.9653
# Epoch 80/100
# 53/53 [==============================] - 16s 309ms/step - loss: 0.2520 - acc: 0.8931 - val_loss: 0.0073 - val_acc: 0.9689
# Epoch 81/100
# 53/53 [==============================] - 16s 293ms/step - loss: 0.2448 - acc: 0.9081 - val_loss: 0.0073 - val_acc: 0.9641
# Epoch 82/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.2552 - acc: 0.8967 - val_loss: 0.0073 - val_acc: 0.9629
# Epoch 83/100
# 53/53 [==============================] - 16s 296ms/step - loss: 0.2467 - acc: 0.9146 - val_loss: 0.0073 - val_acc: 0.9617
# Epoch 84/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.2364 - acc: 0.9015 - val_loss: 0.0073 - val_acc: 0.9545
# Epoch 85/100
# 53/53 [==============================] - 18s 339ms/step - loss: 0.2488 - acc: 0.9009 - val_loss: 0.0073 - val_acc: 0.9677
# Epoch 86/100
# 53/53 [==============================] - 16s 302ms/step - loss: 0.2403 - acc: 0.9099 - val_loss: 0.0073 - val_acc: 0.9521
# Epoch 87/100
# 53/53 [==============================] - 16s 306ms/step - loss: 0.2649 - acc: 0.8955 - val_loss: 0.0072 - val_acc: 0.9557
# Epoch 88/100
# 53/53 [==============================] - 16s 305ms/step - loss: 0.2509 - acc: 0.9134 - val_loss: 0.0073 - val_acc: 0.9509
# Epoch 89/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.2401 - acc: 0.9104 - val_loss: 0.0072 - val_acc: 0.9545
# Epoch 90/100
# 53/53 [==============================] - 16s 299ms/step - loss: 0.2483 - acc: 0.9093 - val_loss: 0.0072 - val_acc: 0.9509
# Epoch 91/100
# 53/53 [==============================] - 16s 301ms/step - loss: 0.2415 - acc: 0.9128 - val_loss: 0.0072 - val_acc: 0.9653
# Epoch 92/100
# 53/53 [==============================] - 16s 293ms/step - loss: 0.2408 - acc: 0.9045 - val_loss: 0.0072 - val_acc: 0.9581
# Epoch 93/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.2626 - acc: 0.9003 - val_loss: 0.0071 - val_acc: 0.9593
# Epoch 94/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.2509 - acc: 0.9045 - val_loss: 0.0071 - val_acc: 0.9617
# Epoch 95/100
# 53/53 [==============================] - 16s 300ms/step - loss: 0.2466 - acc: 0.9021 - val_loss: 0.0071 - val_acc: 0.9677
# Epoch 96/100
# 53/53 [==============================] - 16s 301ms/step - loss: 0.2323 - acc: 0.9128 - val_loss: 0.0071 - val_acc: 0.9593
# Epoch 97/100
# 53/53 [==============================] - 16s 303ms/step - loss: 0.2574 - acc: 0.9122 - val_loss: 0.0083 - val_acc: 0.9629
# Epoch 98/100
# 53/53 [==============================] - 16s 300ms/step - loss: 0.2459 - acc: 0.8949 - val_loss: 0.0071 - val_acc: 0.9653
# Epoch 99/100
# 53/53 [==============================] - 16s 308ms/step - loss: 0.2310 - acc: 0.9045 - val_loss: 0.0071 - val_acc: 0.9557
# Epoch 100/100
# 53/53 [==============================] - 16s 298ms/step - loss: 0.2915 - acc: 0.8848 - val_loss: 0.0070 - val_acc: 0.9629

# %%
model.save('modelQ5.try6') #important do not change the name of the model

import matplotlib.pyplot as plt
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

import numpy as np
test_dir= os.path.join(base_dir, 'test') # very important: do not change this!



datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory(
        test_dir, 
        target_size=(150, 150), 
        batch_size=32, 
        class_mode='categorical')

loss , acc = model.evaluate_generator(generator=test_generator)
print("test accuracy: {:5.2f}%".format(100*acc))
# Out:
# Found 200 images belonging to 4 classes.
# test accuracy: 96.50%

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory(
        test_dir, 
        target_size=(150, 150), 
        batch_size=10, 
        class_mode='categorical', shuffle=False)

#loss , acc = model.evaluate_generator(generator=test_generator, verbose=1)
#test_generator.reset()
pred = model.predict_generator(generator=test_generator, verbose=1)


predicted_class_indices = np.argmax(pred, axis=1)
#print("predicted_class_indices ", predicted_class_indices)
labels = (test_generator.class_indices)
#print(labels)
label = dict((v,k) for k,v in labels.items())
predictions = [label[i] for i in predicted_class_indices]

filenames = test_generator.filenames

label_to_class_name = {
    'c0' : 'cat',
    'c1' : 'dog',
    'c2' : 'car',
    'c3' : 'motorbike'
}
count = 0
for idx in range(len(filenames )):
    y_hat = predictions[idx]
    y = filenames[idx].split('/')[0]
    if y_hat != y:
        print('predict  ' , label_to_class_name[y_hat])
        print('true value ', label_to_class_name[y])    
        print('filename    ' , filenames[idx])
        count += 1
print('failed ', count)
#test_sets = test_generator.next()
#for test in test_sets:
#    output = conv_base.predict(test)
    #print(output.shape)
    #result = model.predict(output)
    #print(result[0])
# Out:
# Found 200 images belonging to 4 classes.
# 20/20 [==============================] - 1s 39ms/step
# predict   dog
# true value  cat
# filename     c0/cat_0688.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0527.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0528.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0531.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0533.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0551.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0552.jpg
# failed  7

# %%
datagen = ImageDataGenerator(rescale=1./255)

validation_generator = datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical', shuffle=False)

#loss , acc = model.evaluate_generator(generator=test_generator, verbose=1)
#test_generator.reset()
pred = model.predict_generator(generator=validation_generator, verbose=1)


predicted_class_indices = np.argmax(pred, axis=1)
#print("predicted_class_indices ", predicted_class_indices)
labels = (validation_generator.class_indices)
#print(labels)
label = dict((v,k) for k,v in labels.items())
predictions = [label[i] for i in predicted_class_indices]

filenames = validation_generator.filenames

label_to_class_name = {
    'c0' : 'cat',
    'c1' : 'dog',
    'c2' : 'car',
    'c3' : 'motorbike'
}
count = 0
for idx in range(len(filenames )):
    y_hat = predictions[idx]
    y = filenames[idx].split('/')[0]
    if y_hat != y:
        print('predict  ' , label_to_class_name[y_hat])
        print('true value ', label_to_class_name[y])    
        print('filename    ' , filenames[idx])
        count += 1
print('failed ', count)
# Out:
# Found 835 images belonging to 4 classes.
# 27/27 [==============================] - 3s 106ms/step
# predict   dog
# true value  cat
# filename     c0/cat_0448.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0457.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0469.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0484.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0496.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0514.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0535.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0586.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0589.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0596.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0623.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0635.jpg
# predict   dog
# true value  cat
# filename     c0/cat_0641.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0365.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0370.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0390.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0404.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0407.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0415.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0429.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0438.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0448.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0453.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0470.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0488.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0497.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0515.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0517.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0519.jpg
# predict   cat
# true value  dog
# filename     c1/dog_0522.jpg
# predict   car
# true value  motorbike
# filename     c3/motorbike_0506.jpg
# failed  31
